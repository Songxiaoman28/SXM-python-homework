# %% [markdown]
# # matplotlib exercises

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Q1: planetary positions
#
# The distances of the planets from the Sun (technically, their semi-major axes) are:

# %%
a = np.array([0.39, 0.72, 1.00, 1.52, 5.20, 9.54, 19.22, 30.06, 39.48]) #行星到太阳的距离

# %% [markdown]
# These are in units where the Earth-Sun distance is 1 (astronomical units).
#
# The corresponding periods of their orbits (how long they take to go once around the Sun) are, in years

# %%
P = np.array([0.24, 0.62, 1.00, 1.88, 11.86, 29.46, 84.01, 164.8, 248.09])#周期

# %% [markdown]
# Finally, the names of the planets corresponding to these are:

# %%
names = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", 
         "Uranus", "Neptune", "Pluto"] #行星名字

# %% [markdown]
# (technically, pluto isn't a planet anymore, but we still love it :)
#
#   * Plot as points, the periods vs. distances for each planet on a log-log plot.
#
#   * Write the name of the planet next to the point for that planet on the plot

# %%
lna=np.log(a)
lnP=np.log(P)
fig=plt.figure()
fig, ax = plt.subplots()
ax.scatter(lna,lnP)
ax.set_title('the periods vs. distances for each planet')
ax.set_xlabel('lna')
ax.set_ylabel('lnP')
for i,j in enumerate(names):
    ax.annotate(j,(lna[i],lnP[i])) #每个点添加标签

# %% [markdown]
# ## Q2: drawing a circle
#
# For an angle $\theta$ in the range $\theta \in [0, 2\pi]$, the polar equations of a circle of radius $R$ are:
# $$
# x = R\cos(\theta)
# $$
# $$
# y = R\sin(\theta)
# $$
#
# We want to draw a circle.
#
#   * Create an array to hold the theta values&mdash;the more we use, the smoother the circle will be
#   * Create `x` and `y` arrays from `theta` for your choice of $R$
#   * Plot `y` vs. `x`
#
# Now, look up the matplotlib `fill()` function, and draw a circle filled in with a solid color.

# %%
theta = np.linspace(0,2*np.pi,100000)
x=np.cos(theta)
y=np.sin(theta)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.fill(x,y,color='r',alpha=0.5)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Q3: Circles, circles, circles...
#
# Generalize your circle drawing commands to produce a function,
# ```
# draw_circle(x0, y0, R, color)
# ```
# that draws the circle.  Here, `(x0, y0)` is the center of the circle, `R` is the radius, and `color` is the color of the circle.
#
# Now randomly draw 10 circles at different locations, with random radii, and random colors on the same plot.

# %%
#定义函数，随机画圆
fig = plt.figure()
ax = plt.subplot(111)
theta = np.arange(0, 2*np.pi, 0.01)
def draw_circle(x0, y0, R, color):
    x = x0+ R* np.cos(theta)
    y = y0+ R* np.sin(theta)
    return (ax.plot(x, y),ax.fill(x,y,color))
R=np.random.randint(1,5,10) #半径
x0=np.random.randint(-10,10,10)
y0=np.random.randint(-10,10,10) #圆心
color=np.random.randint(0,20,10)
#color=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w','#008000','#FFA500'] #颜色
for i in range(10):
    draw_circle(x0[i],y0[i],R[i],color[i])
ax.axis('equal')
plt.show()

# %% [markdown]
# ## Q4: Climate
#
# Download the data file of global surface air temperature averages from here:
# https://raw.githubusercontent.com/sbu-python-summer/python-tutorial/master/day-4/nasa-giss.txt
#
# (this data comes from: https://data.giss.nasa.gov/gistemp/graphs/)
#
# There are 3 columns here: the year, the temperature change, and a smoothed representation of the temperature change.
#
#   * Read in this data using `np.loadtxt()`.
#   * Plot as a line the smoothed representation of the temperature changes.
#   * Plot as points the temperature change (no smoothing).  Color the points blue if they are < 0 and color them red if they are >= 0
#
# You might find the NumPy `where()` function useful.

# %%
Climate=np.loadtxt('nasa-giss.txt')
year=Climate[:,0]
tc=Climate[:,1]
stc=Climate[:,2]

plt.plot(year,stc)
plt.title('a smoothed representation of the temperature change')
plt.xlabel('year')
plt.ylabel('smooth temperature change')
plt.show()

# %%
plt.plot(year[np.where(tc<0)],tc[np.where(tc<0)],'bo')
plt.plot(year[np.where(tc>=0)],tc[np.where(tc>=0)],'ro')
plt.title('the temperature change')
plt.xlabel('year')
plt.ylabel('temperature change')
plt.show()

# %% [markdown]
# ## Q5: subplots
#
# matplotlib has a number of ways to create multiple axes in a figure -- look at `plt.subplot()` (http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot)
#
# Create an `x` array using NumPy with a number of points, spanning from $[0, 2\pi]$.
#
# Create 3 axes vertically, and do the following:
#
# * Define a new numpy array `f` initialized to a function of your choice.
# * Plot f in the top axes
# * Compute a numerical derivative of `f`,
#    $$ f' = \frac{f_{i+1} - f_i}{\Delta x}$$
#   and plot this in the middle axes
# * Do this again, this time on $f'$ to compute the second derivative and plot that in the bottom axes

# %%
x=np.arange(0,2*np.pi,0.1)
dx=0.1
f_x=np.sin(x)
df_x=np.diff(f_x)/dx #一阶导
ddf_x=np.diff(df_x)/dx #二阶导

plt.subplot(311)
plt.plot(x,f_x)
plt.ylabel('f(x)')

plt.subplot(312)
plt.plot(x[:-1],df_x)
plt.ylabel('df(x)')

plt.subplot(313)
plt.plot(x[:-2],ddf_x)
plt.ylabel('ddf(x)')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Q6: frequent words plotting
#
# In this exercise, we will read the file with the transcription of _Star Trek TOS, Shore Leave_ and calculate the amount of time each word was found. We will then plot the 25 most frequent words and label the plot.
#
# ### 6.1 Read the file and create the dictionaty {'word':count}
#
#    * Open the `shore_leave.txt`
#    * Create the dictionary of the form {'word':count}, where `count` shows the amount of times the word was found in the text. Remember to get rid of the punctuation ("." and ",") and to ensure that all words are lowercase

# %%
f = open("shore_leave.txt", "r") 
mydict={'shore':0}
for line in f:
    newline=line.replace('.',' ').replace(',',' ').split() #去掉标点,并分裂
    for word in newline:
        sum_word=word[0].lower()+word[1:] #转为小写
        if sum_word in mydict.keys():
            mydict[sum_word]=mydict[sum_word]+1 #计数
        else:
            mydict[sum_word]=1
import operator
mydict.items()#以列表返回可遍历的(键, 值) 元组数组
sorted_mydict=sorted(mydict.items(),key=operator.itemgetter(1)) #按值进行升序
sorted_mydict
# Out:
# [('female', 1),
#  ('signature', 1),
#  ('sending', 1),
#  ('momentarily', 1),
#  ('stretches', 1),
#  ('groans', 1),
#  ('kink', 1),
#  ('starts', 1),
#  ('massage', 1),
#  ('higher', 1),
#  ('please', 1),
#  ('dig', 1),
#  ('steps', 1),
#  ('forward', 1),
#  ('realises', 1),
#  ('massaging', 1),
#  ('lower', 1),
#  ('enough', 1),
#  ('correct', 1),
#  ('last', 1),
#  ('months', 1),
#  ('excepted', 1),
#  ('channeled', 1),
#  ('worries', 1),
#  ('prescribed', 1),
#  ('weary', 1),
#  ('authorise', 1),
#  ('depending', 1),
#  ('upon', 1),
#  ('mine', 1),
#  ('four', 1),
#  ('hundred', 1),
#  ('thirty', 1),
#  ('cellstructure', 1),
#  ('records', 1),
#  ('blade', 1),
#  ('bush', 1),
#  ('petal', 1),
#  ('biology', 1),
#  ('crouches', 1),
#  ('pampas', 1),
#  ('check', 1),
#  ('jacket', 1),
#  ('pocketwatch', 1),
#  ('paws', 1),
#  ('whiskers', 1),
#  ('blue', 1),
#  ('apron', 1),
#  ('gloves', 1),
#  ('wordlessly', 1),
#  ('points', 1),
#  ('went', 1),
#  ('curtseys', 1),
#  ('nicely', 1),
#  ('doc', 1),
#  ('dictating', 1),
#  ('presence', 1),
#  ('omicron', 1),
#  ('delta', 1),
#  ('region', 1),
#  ('remarkably', 1),
#  ('parklike', 1),
#  ('flowers', 1),
#  ('lawn', 1),
#  ('quiet', 1),
#  ('falling', 1),
#  ('apart', 1),
#  ('dismissed', 1),
#  ('enters', 1),
#  ('starboard', 1),
#  ('case', 1),
#  ('cease', 1),
#  ('instead', 1),
#  ('saving', 1),
#  ('intercom', 1),
#  ('whistles', 1),
#  ('open', 1),
#  ('channel', 1),
#  ('uhura', 1),
#  ('planned', 1),
#  ('probes', 1),
#  ('detectors', 1),
#  ('malfunctioning', 1),
#  ('careless', 1),
#  ('beautyintoxicated', 1),
#  ('unfit', 1),
#  ('pull', 1),
#  ('watch', 1),
#  ('vest', 1),
#  ('claim', 1),
#  ('pretty', 1),
#  ('followed', 1),
#  ('disappeared', 1),
#  ('hedge', 1),
#  ('under', 1),
#  ('consideration', 1),
#  ('pill', 1),
#  ('mystery', 1),
#  ('sugarcoating', 1),
#  ('wants', 1),
#  ('swallow', 1),
#  ('discuss', 1),
#  ('crewmember', 1),
#  ('showing', 1),
#  ('signs', 1),
#  ('stress', 1),
#  ('fatigue', 1),
#  ('reaction', 1),
#  ('nine', 1),
#  ('twelve', 1),
#  ('percent', 1),
#  ('associational', 1),
#  ('reading', 1),
#  ('norm', 1),
#  ('minus', 1),
#  ('low', 1),
#  ('rating', 1),
#  ('becoming', 1),
#  ('irritable', 1),
#  ('quarrelsome', 1),
#  ('refuses', 1),
#  ('rehabilitation', 1),
#  ('safety', 1),
#  ('begins', 1),
#  ('james', 1),
#  ('yourself', 1),
#  ('establishing', 1),
#  ('landscape', 1),
#  ('artefacts', 1),
#  ('fields', 1),
#  ('peace', 1),
#  ('sunshine', 1),
#  ('words', 1),
#  ('spoken', 1),
#  ('raises', 1),
#  ('itself', 1),
#  ('reveal', 1),
#  ('classic', 1),
#  ('westernstyle', 1),
#  ('six', 1),
#  ('shooter', 1),
#  ('elsewhere', 1),
#  ('taking', 1),
#  ('scans', 1),
#  ('vegetation', 1),
#  ('loveliness', 1),
#  ('asks', 1),
#  ('completed', 1),
#  ('specimen', 1),
#  ('survey', 1),
#  ('enjoying', 1),
#  ('yourselves', 1),
#  ('exists', 1),
#  ('affirmative', 1),
#  ('lake', 1),
#  ('jokes', 1),
#  ('lately', 1),
#  ('pair', 1),
#  ('soil', 1),
#  ('maybe', 1),
#  ('hallucinated', 1),
#  ('creature', 1),
#  ('size', 1),
#  ('confirm', 1),
#  ('examining', 1),
#  ('flora', 1),
#  ('collecting', 1),
#  ('specimens', 1),
#  ('beamed', 1),
#  ('message', 1),
#  ('cancelling', 1),
#  ('account', 1),
#  ('probably', 1),
#  ('bring', 1),
#  ('proof', 1),
#  ('gunshot', 1),
#  ('fired', 1),
#  ('practising', 1),
#  ('shooting', 1),
#  ('beauty', 1),
#  ('collection', 1),
#  ('coincidence', 1),
#  ('lying', 1),
#  ('oldtime', 1),
#  ('police', 1),
#  ('special', 1),
#  ('condition', 1),
#  ('centuries', 1),
#  ('holding', 1),
#  ('offending', 1),
#  ('fires', 1),
#  ('pellets', 1),
#  ('propelled', 1),
#  ('expanding', 1),
#  ('gases', 1),
#  ('chemical', 1),
#  ('explosion', 1),
#  ('hang', 1),
#  ('fresh', 1),
#  ('seems', 1),
#  ('triggerhappy', 1),
#  ('mammals', 1),
#  ('insects', 1),
#  ('elaborate', 1),
#  ('gag', 1),
#  ('accompany', 1),
#  ('area', 1),
#  ('view', 1),
#  ('follows', 1),
#  ('turning', 1),
#  ('worse', 1),
#  ('persecution', 1),
#  ('bit', 1),
#  ('upper', 1),
#  ('classman', 1),
#  ('practical', 1),
#  ('joke', 1),
#  ('confession', 1),
#  ('grim', 1),
#  ('delighted', 1),
#  ('end', 1),
#  ('bowl', 1),
#  ('soup', 1),
#  ('bed', 1),
#  ('bucket', 1),
#  ('water', 1),
#  ('propped', 1),
#  ('halfopen', 1),
#  ('door', 1),
#  ('knew', 1),
#  ('next', 1),
#  ('follow', 1),
#  ('backtrack', 1),
#  ('side', 1),
#  ('hill', 1),
#  ('grudge', 1),
#  ('split', 1),
#  ('leaning', 1),
#  ('trunk', 1),
#  ('dreadful', 1),
#  ('codIrish', 1),
#  ('accent', 1),
#  ('hits', 1),
#  ('maniacal', 1),
#  ('laughter', 1),
#  ('lay', 1),
#  ('try', 1),
#  ('lays', 1),
#  ('investigate', 1),
#  ('meets', 1),
#  ('disheveled', 1),
#  ('hugging', 1),
#  ('following', 1),
#  ('give', 1),
#  ('cloak', 1),
#  ('dagger', 1),
#  ('jewels', 1),
#  ('imagining', 1),
#  ('incredible', 1),
#  ('than', 1),
#  ('imagined', 1),
#  ('story', 1),
#  ('book', 1),
#  ('dreaming', 1),
#  ('ran', 1),
#  ('indicates', 1),
#  ('monitors', 1),
#  ('across', 1),
#  ('barren', 1),
#  ('piece', 1),
#  ('gains', 1),
#  ('palms', 1),
#  ('banana', 1),
#  ('picks', 1),
#  ('orange', 1),
#  ('becomes', 1),
#  ('wistful', 1),
#  ('roses', 1),
#  ('darling', 1),
#  ('kisses', 1),
#  ('stardate', 1),
#  ('increasingly', 1),
#  ('continues', 1),
#  ('seeing', 1),
#  ('exist', 1),
#  ('undeniably', 1),
#  ('aged', 1),
#  ('matters', 1),
#  ('flock', 1),
#  ('showed', 1),
#  ('offhand', 1),
#  ('defective', 1),
#  ('lifeforms', 1),
#  ('search', 1),
#  ('specify', 1),
#  ('highly', 1),
#  ('sophisticated', 1),
#  ('type', 1),
#  ('draining', 1),
#  ('increasing', 1),
#  ('affect', 1),
#  ('pinpoint', 1),
#  ('beneath', 1),
#  ('patterns', 1),
#  ('indicate', 1),
#  ('industrial', 1),
#  ('activity', 1),
#  ('keep', 1),
#  ('posted', 1),
#  ('meanwhile', 1),
#  ('monitoring', 1),
#  ('tropical', 1),
#  ('alone', 1),
#  ('tunic', 1),
#  ('dressed', 1),
#  ('fairytale', 1),
#  ('lots', 1),
#  ('floaty', 1),
#  ('stuff', 1),
#  ('tall', 1),
#  ('hat', 1),
#  ('veil', 1),
#  ('armies', 1),
#  ('juans', 1),
#  ('promise', 1),
#  ('takes', 1),
#  ('gaze', 1),
#  ('eyes', 1),
#  ('spots', 1),
#  ('dream', 1),
#  ('clothing', 1),
#  ('hanging', 1),
#  ('shrubs', 1),
#  ('protected', 1),
#  ('fought', 1),
#  ('blood', 1),
#  ('royale', 1),
#  ('many', 1),
#  ('lovelier', 1),
#  ('dear', 1),
#  ('volume', 1),
#  ('their', 1),
#  ('bored', 1),
#  ('emerges', 1),
#  ('changing', 1),
#  ('room', 1),
#  ('happy', 1),
#  ('disney', 1),
#  ('fantasy', 1),
#  ('creation', 1),
#  ('science', 1),
#  ('refined', 1),
#  ('metal', 1),
#  ('chance', 1),
#  ('hallucination', 1),
#  ('flattened', 1),
#  ('clout', 1),
#  ('painful', 1),
#  ('reality', 1),
#  ('logical', 1),
#  ('explanation', 1),
#  ('signal', 1),
#  ('weak', 1),
#  ('gain', 1),
#  ('maximum', 1),
#  ('shall', 1),
#  ('phasers', 1),
#  ('besides', 1),
#  ('danger', 1),
#  ('geese', 1),
#  ('flying', 1),
#  ('hatch', 1),
#  ('opens', 1),
#  ('forced', 1),
#  ('dodge', 1),
#  ('sharp', 1),
#  ('rocks', 1),
#  ('cover', 1),
#  ('personalities', 1),
#  ('call', 1),
#  ('few', 1),
#  ('minutes', 1),
#  ('rendezvousing', 1),
#  ('hope', 1),
#  ('everybody', 1),
#  ('checks', 1),
#  ('trying', 1),
#  ('obstructing', 1),
#  ('familiar', 1),
#  ('shape', 1),
#  ('fully', 1),
#  ('materialises', 1),
#  ('unable', 1),
#  ('useless', 1),
#  ('soaking', 1),
#  ('calculated', 1),
#  ('rate', 1),
#  ('its', 1),
#  ('growth', 1),
#  ('reasoned', 1),
#  ('might', 1),
#  ('able', 1),
#  ('transport', 1),
#  ('person', 1),
#  ('help', 1),
#  ('stranded', 1),
#  ('swear', 1),
#  ('heard', 1),
#  ('moving', 1),
#  ('brave', 1),
#  ('protect', 1),
#  ('trio', 1),
#  ('snarl', 1),
#  ('big', 1),
#  ('cat', 1),
#  ('spread', 1),
#  ('armour', 1),
#  ('appeared', 1),
#  ('harm', 1),
#  ('lowers', 1),
#  ('lance', 1),
#  ('charges', 1),
#  ('confiscated', 1),
#  ('shoots', 1),
#  ('supplemental', 1),
#  ('lost', 1),
#  ('friend', 1),
#  ('whatever', 1),
#  ('facing', 1),
#  ('terribly', 1),
#  ('blame', 1),
#  ('trouble', 1),
#  ('every', 1),
#  ('alert', 1),
#  ('goes', 1),
#  ('plastic', 1),
#  ('alive', 1),
#  ('operating', 1),
#  ('swap', 1),
#  ('places', 1),
#  ('human', 1),
#  ('skin', 1),
#  ('tissue', 1),
#  ('closely', 1),
#  ('resembles', 1),
#  ('cellular', 1),
#  ('casting', 1),
#  ('wound', 1),
#  ('finer', 1),
#  ('exact', 1),
#  ('judgment', 1),
#  ('definitely', 1),
#  ('mechanical', 1),
#  ('contrivance', 1),
#  ('same', 1),
#  ('basic', 1),
#  ('cell', 1),
#  ('structure', 1),
#  ('plant', 1),
#  ('multicellular', 1),
#  ('castings', 1),
#  ('particular', 1),
#  ('act', 1),
#  ('deadly', 1),
#  ('buzzing', 1),
#  ('flies', 1),
#  ('telling', 1),
#  ('early', 1),
#  ('wars', 1),
#  ('funny', 1),
#  ('vehicles', 1),
#  ('hurt', 1),
#  ('unless', 1),
#  ('strafing', 1),
#  ('descends', 1),
#  ('joins', 1),
#  ('clump', 1),
#  ('having', 1),
#  ('hit', 1),
#  ('watching', 1),
#  ('notices', 1),
#  ('dragged', 1),
#  ('analysis', 1),
#  ('slight', 1),
#  ('possibility', 1),
#  ('slim', 1),
#  ('nevertheless', 1),
#  ('described', 1),
#  ('days', 1),
#  ('brought', 1),
#  ('reinforcements', 1),
#  ('ha', 1),
#  ('laughs', 1),
#  ('problem', 1),
#  ('wait', 1),
#  ('catches', 1),
#  ('lounging', 1),
#  ('ledge', 1),
#  ('jumps', 1),
#  ('fair', 1),
#  ('gentleman', 1),
#  ('stupid', 1),
#  ('underclassman', 1),
#  ('edge', 1),
#  ('twenty', 1),
#  ('till', 1),
#  ('slope', 1),
#  ('writhing', 1),
#  ('pain', 1),
#  ('move', 1),
#  ('kicked', 1),
#  ('passes', 1),
#  ('sweet', 1),
#  ('regains', 1),
#  ('consciousness', 1),
#  ('learn', 1),
#  ('earn', 1),
#  ('throws', 1),
#  ('dirt', 1),
#  ('exchange', 1),
#  ('bad', 1),
#  ('lot', 1),
#  ('answer', 1),
#  ('plebes', 1),
#  ('plebe', 1),
#  ('today', 1),
#  ('expect', 1),
#  ('lands', 1),
#  ('final', 1),
#  ('haymaker', 1),
#  ('enjoyed', 1),
#  ('realisation', 1),
#  ('dawns', 1),
#  ('beat', 1),
#  ('tar', 1),
#  ('supports', 1),
#  ('theory', 1),
#  ('formulating', 1),
#  ('meeting', 1),
#  ('moment', 1),
#  ('somehow', 1),
#  ('quickly', 1),
#  ('provided', 1),
#  ('dangerous', 1),
#  ('control', 1),
#  ('difficult', 1),
#  ('underground', 1),
#  ('manufacturing', 1),
#  ('passages', 1),
#  ('example', 1),
#  ('thought', 1),
#  ('chain', 1),
#  ('neck', 1),
#  ('tethering', 1),
#  ('spot', 1),
#  ('clearly', 1),
#  ('visible', 1),
#  ('warn', 1),
#  ('aircraft', 1),
#  ('strafe', 1),
#  ('elbows', 1),
#  ('changed', 1),
#  ('sneaks', 1),
#  ('grabs', 1),
#  ('warding', 1),
#  ('rodriquez', 1),
#  ('centre', 1),
#  ('ask', 1),
#  ('breathe', 1),
#  ('attention', 1),
#  ('smiling', 1),
#  ('greyhaired', 1),
#  ('robe', 1),
#  ('caretaker', 1),
#  ('discovered', 1),
#  ('experiences', 1),
#  ('intended', 1),
#  ('word', 1),
#  ('permanent', 1),
#  ('fondest', 1),
#  ('wishes', 1),
#  ('relive', 1),
#  ('new', 1),
#  ('battle', 1),
#  ('fear', 1),
#  ('love', 1),
#  ('triumph', 1),
#  ('pleases', 1),
#  ('term', 1),
#  ('park', 1),
#  ('sorts', 1),
#  ('fascinating', 1),
#  ('entire', 1),
#  ('constructed', 1),
#  ('advanced', 1),
#  ('mind', 1),
#  ('greater', 1),
#  ('simplicity', 1),
#  ('perceptive', 1),
#  ('died', 1),
#  ('strolls', 1),
#  ('taken', 1),
#  ('below', 1),
#  ('remarkable', 1),
#  ('amazing', 1),
#  ('factory', 1),
#  ('build', 1),
#  ('immediately', 1),
#  ('amused', 1),
#  ('rigel', 1),
#  ('chorus', 1),
#  ('l', 1),
#  ('suppose', 1),
#  ('regret', 1),
#  ('uncomfortable', 1),
#  ('built', 1),
#  ('impression', 1),
#  ('tend', 1),
#  ('agree', 1),
#  ('systems', 1),
#  ('require', 1),
#  ('assistance', 1),
#  ('however', 1),
#  ('proper', 1),
#  ('caution', 1),
#  ('ideal', 1),
#  ('themselves', 1),
#  ('commence', 1),
#  ('transporting', 1),
#  ('prepare', 1),
#  ('best', 1),
#  ('due', 1),
#  ('respect', 1),
#  ('care', 1),
#  ('group', 1),
#  ('gentlemen', 1),
#  ('most', 1),
#  ('warp', 1),
#  ('factor', 1),
#  ('enterprise', 2),
#  ('orbiting', 2),
#  ('landing', 2),
#  ('push', 2),
#  ('hard', 2),
#  ('sufficient', 2),
#  ('three', 2),
#  ('ordered', 2),
#  ('scouting', 2),
#  ('alice', 2),
#  ('wonderland', 2),
#  ('needs', 2),
#  ('ours', 2),
#  ('plus', 2),
#  ('going', 2),
#  ('flower', 2),
#  ('turns', 2),
#  ('straight', 2),
#  ('yellow', 2),
#  ('waistcoat', 2),
#  ('looking', 2),
#  ('gold', 2),
#  ('late', 2),
#  ('heads', 2),
#  ('hole', 2),
#  ('running', 2),
#  ('wearing', 2),
#  ('excuse', 2),
#  ('rather', 2),
#  ('uninhabited', 2),
#  ('true', 2),
#  ('may', 2),
#  ('tired', 2),
#  ('leaves', 2),
#  ('section', 2),
#  ('necessary', 2),
#  ('using', 2),
#  ('quite', 2),
#  ('illogical', 2),
#  ('calling', 2),
#  ('scouts', 2),
#  ('duty', 2),
#  ('supposedly', 2),
#  ('picked', 2),
#  ('time', 2),
#  ('ends', 2),
#  ('interesting', 2),
#  ('pleasant', 2),
#  ('shot', 2),
#  ('detected', 2),
#  ('force', 2),
#  ('rock', 2),
#  ('woman', 2),
#  ('work', 2),
#  ('teller', 2),
#  ('everything', 2),
#  ('footprints', 2),
#  ('neither', 2),
#  ('admit', 2),
#  ('draws', 2),
#  ('target', 2),
#  ('doing', 2),
#  ('crazy', 2),
#  ('couple', 2),
#  ('hand', 2),
#  ('weapon', 2),
#  ('lead', 2),
#  ('instruments', 2),
#  ('show', 2),
#  ('animal', 2),
#  ('life', 2),
#  ('absolutely', 2),
#  ('nothing', 2),
#  ('readings', 2),
#  ('those', 2),
#  ('came', 2),
#  ('another', 2),
#  ('aerial', 2),
#  ('point', 2),
#  ('yeah', 2),
#  ('beginning', 2),
#  ('feeling', 2),
#  ('academy', 2),
#  ('devil', 2),
#  ('guy', 2),
#  ('serious', 2),
#  ('put', 2),
#  ('cold', 2),
#  ('strike', 2),
#  ('chasing', 2),
#  ('against', 2),
#  ('suddenly', 2),
#  ('huh', 2),
#  ('jaw', 2),
#  ('ahead', 2),
#  ('again', 2),
#  ('screams', 2),
#  ('baby', 2),
#  ('arrive', 2),
#  ('scene', 2),
#  ('uniform', 2),
#  ('torn', 2),
#  ('happened', 2),
#  ('imagine', 2),
#  ('day', 2),
#  ('half', 2),
#  ('investigation', 2),
#  ('fifteen', 2),
#  ('none', 2),
#  ('fine', 2),
#  ('surveys', 2),
#  ('say', 2),
#  ('indeed', 2),
#  ('waiting', 2),
#  ('strange', 2),
#  ('source', 2),
#  ('continue', 2),
#  ('met', 2),
#  ('each', 2),
#  ('others', 2),
#  ('second', 2),
#  ('lady', 2),
#  ('peek', 2),
#  ('trapped', 2),
#  ('officer', 2),
#  ('hallucinations', 2),
#  ('turn', 2),
#  ('already', 2),
#  ('armed', 2),
#  ('sees', 2),
#  ('overhead', 2),
#  ('cliff', 2),
#  ('attack', 2),
#  ('sword', 2),
#  ('said', 2),
#  ('transporter', 2),
#  ('finally', 2),
#  ('contact', 2),
#  ('until', 2),
#  ('talk', 2),
#  ('horse', 2),
#  ('dead', 2),
#  ('surgeon', 2),
#  ('fault', 2),
#  ('dummy', 2),
#  ('tricorder', 2),
#  ('repairs', 2),
#  ('saying', 2),
#  ('manufactured', 2),
#  ('angela', 2),
#  ('falls', 2),
#  ('everyone', 2),
#  ('scientific', 2),
#  ('death', 2),
#  ('encountered', 2),
#  ('hey', 2),
#  ('happening', 2),
#  ('order', 2),
#  ('both', 2),
#  ('because', 2),
#  ('knocks', 2),
#  ('resumes', 2),
#  ('punches', 2),
#  ('leg', 2),
#  ('broken', 2),
#  ('later', 2),
#  ('ever', 2),
#  ('questions', 2),
#  ('obviously', 2),
#  ('concentrate', 2),
#  ('amuse', 2),
#  ('ones', 2),
#  ('wish', 2),
#  ('amusement', 2),
#  ('race', 2),
#  ('er', 2),
#  ('cabaret', 2),
#  ('getting', 3),
#  ('wrong', 3),
#  ('line', 3),
#  ('crewman', 3),
#  ('aboard', 3),
#  ('myself', 3),
#  ('animals', 3),
#  ('problems', 3),
#  ('tell', 3),
#  ('whole', 3),
#  ('looks', 3),
#  ('dress', 3),
#  ('seen', 3),
#  ('large', 3),
#  ('direction', 3),
#  ('remember', 3),
#  ('trees', 3),
#  ('restful', 3),
#  ('almost', 3),
#  ('beaming', 3),
#  ('either', 3),
#  ('blonde', 3),
#  ('fact', 3),
#  ('afraid', 3),
#  ('orders', 3),
#  ('kind', 3),
#  ('only', 3),
#  ('gun', 3),
#  ('ready', 3),
#  ('start', 3),
#  ('meet', 3),
#  ('make', 3),
#  ('negative', 3),
#  ('stand', 3),
#  ('harmless', 3),
#  ('hear', 3),
#  ('head', 3),
#  ('woodland', 3),
#  ('wanted', 3),
#  ('handing', 3),
#  ('gone', 3),
#  ('certain', 3),
#  ('front', 3),
#  ('complex', 3),
#  ('own', 3),
#  ('personal', 3),
#  ('being', 3),
#  ('let', 3),
#  ('hands', 3),
#  ('away', 3),
#  ('sounds', 3),
#  ('sort', 3),
#  ('someone', 3),
#  ('stay', 3),
#  ('gets', 3),
#  ('black', 3),
#  ('possibly', 3),
#  ('while', 3),
#  ('ago', 3),
#  ('rendezvous', 3),
#  ('told', 3),
#  ('field', 3),
#  ('communications', 3),
#  ('coming', 3),
#  ('walks', 3),
#  ('arm', 3),
#  ('even', 3),
#  ('princess', 3),
#  ('esteban', 3),
#  ('samurai', 3),
#  ('sound', 3),
#  ('use', 3),
#  ('makes', 3),
#  ('body', 3),
#  ('understand', 3),
#  ('exactly', 3),
#  ('plane', 3),
#  ('used', 3),
#  ('thoughts', 3),
#  ('forever', 3),
#  ('happen', 3),
#  ('girls', 3),
#  ('party', 4),
#  ('behind', 4),
#  ('need', 4),
#  ('sleep', 4),
#  ('course', 4),
#  ('better', 4),
#  ('grass', 4),
#  ('earth', 4),
#  ('energy', 4),
#  ('bones', 4),
#  ('must', 4),
#  ('explain', 4),
#  ('found', 4),
#  ('does', 4),
#  ('beam', 4),
#  ('walking', 4),
#  ('unusual', 4),
#  ('phaser', 4),
#  ('made', 4),
#  ('sure', 4),
#  ('birds', 4),
#  ('feel', 4),
#  ('around', 4),
#  ('towards', 4),
#  ('plants', 4),
#  ('into', 4),
#  ('beeps', 4),
#  ('answers', 4),
#  ('power', 4),
#  ('thing', 4),
#  ('tiger', 4),
#  ('two', 4),
#  ('face', 4),
#  ('still', 4),
#  ('old', 4),
#  ('green', 5),
#  ('thank', 5),
#  ('rest', 5),
#  ('lieutenant', 5),
#  ('other', 5),
#  ('parties', 5),
#  ('white', 5),
#  ('oh', 5),
#  ('comes', 5),
#  ('matter', 5),
#  ('log', 5),
#  ('first', 5),
#  ('which', 5),
#  ('had', 5),
#  ('why', 5),
#  ('yet', 5),
#  ('enjoy', 5),
#  ('air', 5),
#  ('always', 5),
#  ('long', 5),
#  ('way', 5),
#  ('along', 5),
#  ('mean', 5),
#  ('tracks', 5),
#  ('before', 5),
#  ('fight', 5),
#  ('juan', 5),
#  ('ground', 5),
#  ('real', 5),
#  ('read', 5),
#  ('years', 5),
#  ('play', 5),
#  ('young', 6),
#  ('anything', 6),
#  ('should', 6),
#  ('something', 6),
#  ('quarters', 6),
#  ('surface', 6),
#  ('think', 6),
#  ('believe', 6),
#  ('tree', 6),
#  ('much', 6),
#  ('she', 6),
#  ('too', 6),
#  ('name', 6),
#  ('us', 6),
#  ('man', 6),
#  ('lovely', 6),
#  ('path', 6),
#  ('glade', 6),
#  ('never', 6),
#  ('jimmy', 6),
#  ('don', 6),
#  ('communicator', 6),
#  ('report', 7),
#  ('who', 7),
#  ('if', 7),
#  ('place', 7),
#  ('tonia', 7),
#  ('barrows', 7),
#  ('saw', 7),
#  ('take', 7),
#  ('so', 7),
#  ('more', 7),
#  ('were', 7),
#  ('boy', 7),
#  ('thinking', 7),
#  ...]

# %% [markdown]
# ### 2. Plot 25 most frequent words
#
# Plot a labelled bar chart of the most frequent 25 words with their frequencies.

# %%
#绘制25个最常见的单词
words=()
counts=[]
for i in range(25):
    words=words+(sorted_mydict[-(i+1)][0],) #降序排单词
    counts.append(sorted_mydict[-(i+1)][1])
words_25=words[0:24]
counts_25=counts[0:24]
print(words_25,counts_25)

b=plt.barh(words_25,counts_25)
plt.xlabel('frequency')
plt.title('the most frequent 25 words')
#添加数据标签
for rect in b:
    w = rect.get_width()
    plt.text(w, rect.get_y()+rect.get_height()/2, '%d' %
             int(w), ha='left', va='center')   
plt.show()
# Out:
# ('the', 'a', 'you', 'i', 'is', 'to', 'and', 'it', 'of', 'not', 'captain', 'have', 'are', 'that', 'this', 'he', 'in', 'on', 'what', 'all', 'sulu', 'we', 'mister', 'kirk') [162, 133, 132, 128, 105, 102, 96, 82, 69, 57, 53, 50, 48, 47, 46, 44, 40, 38, 37, 34, 34, 34, 33, 33]
